# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install kmodes
# Out:
# Requirement already satisfied: kmodes in /usr/local/lib/python3.7/dist-packages (0.11.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.19.5)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.0.1)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from kmodes) (0.22.2.post1)

# %%
#Import modules
import numpy as np
import holidays
import pandas as pd
import seaborn as sns
import pickle
import time
import timeit


import matplotlib.pyplot as plt

# %matplotlib inline

import datetime
import math
from collections import Counter

#scipy
import scipy.stats as stats
from scipy import stats
from scipy.stats import chi2_contingency

#sklearn
import sklearn
from sklearn import ensemble
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_score, log_loss, recall_score 
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import resample
import joblib
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             fbeta_score, make_scorer, classification_report, confusion_matrix)

#for clustering
from sklearn.cluster import KMeans
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score

#other learners
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from kmodes.kmodes import KModes

#imblearn
from imblearn.ensemble import BalancedBaggingClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.ensemble import BalancedRandomForestClassifier

#webscraping
import requests
from bs4 import BeautifulSoup
import re
import urllib
from IPython.core.display import HTML

#time series
import statsmodels.api as sm
from pylab import rcParams
import itertools
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA


#warning ignorer
import warnings
warnings.filterwarnings("ignore")

from IPython.display import Image

# Undersampling and Oversampling for class imbalance
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# Classifiers
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.bagging module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.ensemble.forest module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.ensemble. Anything that cannot be imported from sklearn.ensemble is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Reading in pre-processed and transformed data 
file ='/content/drive/MyDrive/Trial/data/Accidents/Visualized_and_manipulated.csv'
df = pd.read_csv(file, low_memory = False)
# Dropping unnamed column
df.drop(df.columns[0],axis=1,inplace=True)
df.head()
# Out:
#   Accident_Index  Longitude   Latitude  ... Hour  Season accident_seriousness
# 0  201501BS70008  -0.206022  51.496572  ...    7  winter               Severe
# 1  201501BS70009  -0.193610  51.500788  ...    9  winter           Not Severe
# 2  201501BS70015  -0.184495  51.501726  ...    8  winter           Not Severe
# 3  201501BS70026  -0.163102  51.499864  ...   23  winter               Severe
# 4  201501BS70027  -0.192941  51.488548  ...   17  winter           Not Severe
#
# [5 rows x 32 columns]

# %%
#made separate dataframe w. set index that wouldnt effect data vis above
df1=df
#set index to accident_index
df1.set_index('Accident_Index', inplace=True)
df1.head()
# Out:
#                 Longitude   Latitude  ...  Season accident_seriousness
# Accident_Index                        ...
# 201501BS70008   -0.206022  51.496572  ...  winter               Severe
# 201501BS70009   -0.193610  51.500788  ...  winter           Not Severe
# 201501BS70015   -0.184495  51.501726  ...  winter           Not Severe
# 201501BS70026   -0.163102  51.499864  ...  winter               Severe
# 201501BS70027   -0.192941  51.488548  ...  winter           Not Severe
#
# [5 rows x 31 columns]

# %%
df1.shape
# Out:
# (95342, 31)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95342 entries, 201501BS70008 to 2019984107219
# Data columns (total 31 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Longitude                                    95342 non-null  float64
#  1   Latitude                                     95342 non-null  float64
#  2   Police_Force                                 95342 non-null  object
#  3   Accident_Severity                            95342 non-null  object
#  4   Number_of_Vehicles                           95342 non-null  object
#  5   Number_of_Casualties                         95342 non-null  object
#  6   Date                                         95342 non-null  object
#  7   Day_of_Week                                  95342 non-null  object
#  8   Time                                         95342 non-null  object
#  9   Local_Authority_(District)                   95342 non-null  object
#  10  Local_Authority_(Highway)                    95342 non-null  object
#  11  1st_Road_Class                               95342 non-null  object
#  12  Road_Type                                    95342 non-null  object
#  13  Speed_limit                                  95342 non-null  float64
#  14  Junction_Detail                              95342 non-null  object
#  15  Junction_Control                             95342 non-null  object
#  16  2nd_Road_Class                               95342 non-null  object
#  17  Pedestrian_Crossing-Human_Control            95342 non-null  object
#  18  Pedestrian_Crossing-Physical_Facilities      95342 non-null  object
#  19  Light_Conditions                             95342 non-null  object
#  20  Weather_Conditions                           95342 non-null  object
#  21  Road_Surface_Conditions                      95342 non-null  object
#  22  Special_Conditions_at_Site                   95342 non-null  object
#  23  Carriageway_Hazards                          95342 non-null  object
#  24  Urban_or_Rural_Area                          95342 non-null  object
#  25  Did_Police_Officer_Attend_Scene_of_Accident  95342 non-null  object
#  26  Month                                        95342 non-null  int64
#  27  Weekend                                      95342 non-null  int64
#  28  Hour                                         95342 non-null  int64
#  29  Season                                       95342 non-null  object
#  30  accident_seriousness                         95342 non-null  object
# dtypes: float64(3), int64(3), object(25)
# memory usage: 23.3+ MB

# %%
#create a new target variable - Reduced target class from a multi-class classification to a binary classification 
# problem to handle the imbalanced dataset and simplify analysis
df1.loc[df1.Accident_Severity !='Slight', 'Target_Severe_Indicator'] = 1
df1.loc[df1.Accident_Severity =='Slight', 'Target_Severe_Indicator'] = 0

# %%
df1["Target_Severe_Indicator"].value_counts()
# Out:
# 0.0    81220
# 1.0    14122
# Name: Target_Severe_Indicator, dtype: int64

# %%
df1["Accident_Severity"].value_counts()
# Out:
# Slight     81220
# Serious    13352
# Fatal        770
# Name: Accident_Severity, dtype: int64

# %%
df1.head()
# Out:
#                 Longitude  ...  Target_Severe_Indicator
# Accident_Index             ...
# 201501BS70008   -0.206022  ...                      1.0
# 201501BS70009   -0.193610  ...                      0.0
# 201501BS70015   -0.184495  ...                      0.0
# 201501BS70026   -0.163102  ...                      1.0
# 201501BS70027   -0.192941  ...                      0.0
#
# [5 rows x 32 columns]

# %%
print(df1.columns)
# Out:
# Index(['Longitude', 'Latitude', 'Police_Force', 'Accident_Severity',
#        'Number_of_Vehicles', 'Number_of_Casualties', 'Date', 'Day_of_Week',
#        'Time', 'Local_Authority_(District)', 'Local_Authority_(Highway)',
#        '1st_Road_Class', 'Road_Type', 'Speed_limit', 'Junction_Detail',
#        'Junction_Control', '2nd_Road_Class',
#        'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'Month', 'Weekend', 'Hour', 'Season', 'accident_seriousness',
#        'Target_Severe_Indicator'],
#       dtype='object')

# %%
for col in set(df1.columns) - set(df1.describe().columns):
    df1[col] = df1[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95342 entries, 201501BS70008 to 2019984107219
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Longitude                                    95342 non-null  float64
#  1   Latitude                                     95342 non-null  float64
#  2   Police_Force                                 95342 non-null  category
#  3   Accident_Severity                            95342 non-null  category
#  4   Number_of_Vehicles                           95342 non-null  category
#  5   Number_of_Casualties                         95342 non-null  category
#  6   Date                                         95342 non-null  category
#  7   Day_of_Week                                  95342 non-null  category
#  8   Time                                         95342 non-null  category
#  9   Local_Authority_(District)                   95342 non-null  category
#  10  Local_Authority_(Highway)                    95342 non-null  category
#  11  1st_Road_Class                               95342 non-null  category
#  12  Road_Type                                    95342 non-null  category
#  13  Speed_limit                                  95342 non-null  float64
#  14  Junction_Detail                              95342 non-null  category
#  15  Junction_Control                             95342 non-null  category
#  16  2nd_Road_Class                               95342 non-null  category
#  17  Pedestrian_Crossing-Human_Control            95342 non-null  category
#  18  Pedestrian_Crossing-Physical_Facilities      95342 non-null  category
#  19  Light_Conditions                             95342 non-null  category
#  20  Weather_Conditions                           95342 non-null  category
#  21  Road_Surface_Conditions                      95342 non-null  category
#  22  Special_Conditions_at_Site                   95342 non-null  category
#  23  Carriageway_Hazards                          95342 non-null  category
#  24  Urban_or_Rural_Area                          95342 non-null  category
#  25  Did_Police_Officer_Attend_Scene_of_Accident  95342 non-null  category
#  26  Month                                        95342 non-null  int64
#  27  Weekend                                      95342 non-null  int64
#  28  Hour                                         95342 non-null  int64
#  29  Season                                       95342 non-null  category
#  30  accident_seriousness                         95342 non-null  category
#  31  Target_Severe_Indicator                      95342 non-null  float64
# dtypes: category(25), float64(4), int64(3)
# memory usage: 8.5+ MB

# %%
np.random.seed(150)

remove_n = 85342 #Sample size to remove from original dataset
df = df1
drop_indices = np.random.choice(df.index, remove_n, replace=False)
df_subset = df.drop(drop_indices)

# %%
df_subset.shape
df_subset.head()
# Out:
#                 Longitude  ...  Target_Severe_Indicator
# Accident_Index             ...
# 201501BS70033   -0.185515  ...                      0.0
# 201501BS70087   -0.190458  ...                      0.0
# 201501BS70142   -0.194273  ...                      0.0
# 201501BS70193   -0.184191  ...                      0.0
# 201501BS70198   -0.215898  ...                      1.0
#
# [5 rows x 32 columns]

# %%
# 85% to 15% distribution of target class - Proportionality of the original dataset is still maintained
df_subset['Target_Severe_Indicator'].value_counts()
# Out:
# 0.0    8511
# 1.0    1489
# Name: Target_Severe_Indicator, dtype: int64

# %%
df_X = df_subset.drop('Target_Severe_Indicator', axis=1)  
df_Y = df_subset['Target_Severe_Indicator']

# %%
# Converting independent categorical features to Numerical by creating Dummy variables

df_X_dummy = pd.get_dummies(df_X)
#print(dataset_X_dummy.head())

# %%
df_X_dummy.shape
# Out:
# (10000, 2576)

# %%
from sklearn.feature_selection import VarianceThreshold

# threshold set to 87% for variance 
# i.e. if 87% of the column data is the same (i.e. low variation), the column will not be as useful
# in the prediction
thresh=(.85 * (1 - .85))

# %%
# Wrapper function to identify low variance features and remove them from the dataframe 

def get_low_variance_columns(dframe=None, columns=None,
                             skip_columns=None, thresh=0.0,
                             autoremove=False):
    try:
        # get list of all the original df columns
        all_columns = dframe.columns

        # remove `skip_columns`
        remaining_columns = all_columns.drop(skip_columns)

        # get length of new index
        max_index = len(remaining_columns) - 1

        # get indices for `skip_columns`
        skipped_idx = [all_columns.get_loc(column)
                       for column
                       in skip_columns]

        # adjust insert location by the number of columns removed
        # (for non-zero insertion locations) to keep relative
        # locations intact
        for idx, item in enumerate(skipped_idx):
            if item > max_index:
                diff = item - max_index
                skipped_idx[idx] -= diff
            if item == max_index:
                diff = item - len(skip_columns)
                skipped_idx[idx] -= diff
            if idx == 0:
                skipped_idx[idx] = item

        # get values of `skip_columns`
        skipped_values = dframe.iloc[:, skipped_idx].values

        # get dataframe values
        X = dframe.loc[:, remaining_columns].values

        # instantiate VarianceThreshold object
        vt = VarianceThreshold(threshold=thresh)

        # fit vt to data
        vt.fit(X)

        # get the indices of the features that are being kept
        feature_indices = vt.get_support(indices=True)

        # remove low-variance columns from index
        feature_names = [remaining_columns[idx]
                         for idx, _
                         in enumerate(remaining_columns)
                         if idx
                         in feature_indices]

        # get the columns to be removed
        removed_features = list(np.setdiff1d(remaining_columns,
                                             feature_names))
        print("Found {0} low-variance columns."
              .format(len(removed_features)))

        # remove the columns
        if autoremove:
            print("Removing low-variance features.")
            # remove the low-variance columns
            X_removed = vt.transform(X)

            print("Reassembling the dataframe (with low-variance "
                  "features removed).")
            # re-assemble the dataframe
            dframe = pd.DataFrame(data=X_removed,
                                  columns=feature_names)

            # add back the `skip_columns`
            for idx, index in enumerate(skipped_idx):
                dframe.insert(loc=index,
                              column=skip_columns[idx],
                              value=skipped_values[:, idx])
            print("Succesfully removed low-variance columns.")

        # do not remove columns
        else:
            print("No changes have been made to the dataframe.")

    except Exception as e:
        print(e)
        print("Could not remove low-variance features. Something "
              "went wrong.")
        pass

    return dframe, removed_features

# %%
# retrieve new dataframe (with low variance features)
df_X_new, low_var_col = get_low_variance_columns(df_X_dummy,[],[],thresh, True) 
#Set to True to remove low variance columns
# Out:
# Found 2534 low-variance columns.
# Removing low-variance features.
# Reassembling the dataframe (with low-variance features removed).
# Succesfully removed low-variance columns.

# %%
df_X_new.shape
# Out:
# (10000, 42)

# %%
df_X_new.head()
# Out:
#    Longitude   Latitude  ...  Season_summer  Season_winter
# 0  -0.185515  51.483307  ...            0.0            1.0
# 1  -0.190458  51.489409  ...            0.0            1.0
# 2  -0.194273  51.509521  ...            0.0            0.0
# 3  -0.184191  51.484006  ...            0.0            1.0
# 4  -0.215898  51.527746  ...            0.0            0.0
#
# [5 rows x 42 columns]

# %%
df_X_normalized=(df_X_new-df_X_new.min())/(df_X_new.max()-df_X_new.min())

# %%
df_X_normalized.head()
# Out:
#    Longitude  Latitude  ...  Season_summer  Season_winter
# 0   0.773444  0.157348  ...            0.0            1.0
# 1   0.772867  0.158036  ...            0.0            1.0
# 2   0.772421  0.160304  ...            0.0            0.0
# 3   0.773599  0.157427  ...            0.0            1.0
# 4   0.769896  0.162360  ...            0.0            0.0
#
# [5 rows x 42 columns]

# %%
df_X=df_X_normalized.round(3)

# %%
df_X.head(3)
# Out:
#    Longitude  Latitude  ...  Season_summer  Season_winter
# 0      0.773     0.157  ...            0.0            1.0
# 1      0.773     0.158  ...            0.0            1.0
# 2      0.772     0.160  ...            0.0            0.0
#
# [3 rows x 42 columns]

# %%
df_Y.value_counts()
# Out:
# 0.0    8511
# 1.0    1489
# Name: Target_Severe_Indicator, dtype: int64

# %%
from sklearn.model_selection import KFold,GridSearchCV

# %%
# 80 train -20 test split
X_train, X_test, y_train, y_test = train_test_split(df_X, df_Y, test_size=0.2, random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((8000, 42), (8000,))

# %%
X_test.shape, y_test.shape
# Out:
# ((2000, 42), (2000,))

# %%
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix

# %%
def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    '''
    print the accuracy score, classification report and confusion matrix of classifier
    '''
    if train:
        '''
        training performance
        '''
        print("Train Result:\n")
        print("accuracy score: {0:.4f}\n".format(accuracy_score(y_train, clf.predict(X_train))))
        print("Classification Report: \n {}\n".format(classification_report(y_train, clf.predict(X_train))))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_train, clf.predict(X_train))))

        res = cross_val_score(clf, X_train, y_train, cv=10, scoring='accuracy')
        print("Average Accuracy: \t {0:.4f}".format(np.mean(res)))
        print("Accuracy SD: \t\t {0:.4f}".format(np.std(res)))

        
    elif train==False:
        '''
        test performance
        '''
        print("Test Result:\n")        
        print("accuracy score: {0:.4f}\n".format(accuracy_score(y_test, clf.predict(X_test))))
        print("Classification Report: \n {}\n".format(classification_report(y_test, clf.predict(X_test))))
        print("Confusion Matrix: \n {}\n".format(confusion_matrix(y_test, clf.predict(X_test))))

# %%
from sklearn.naive_bayes import GaussianNB
gnv_clf = GaussianNB()
gnv_clf.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
print_score(gnv_clf, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# accuracy score: 0.7751
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.86      0.87      6823
#          1.0       0.26      0.28      0.27      1177
#
#     accuracy                           0.78      8000
#    macro avg       0.57      0.57      0.57      8000
# weighted avg       0.78      0.78      0.78      8000
#
#
# Confusion Matrix:
#  [[5869  954]
#  [ 845  332]]
#
# Average Accuracy: 	 0.7700
# Accuracy SD: 		 0.0168

# %%
print_score(gnv_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Test Result:
#
# accuracy score: 0.7770
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.87      0.87      1688
#          1.0       0.28      0.27      0.28       312
#
#     accuracy                           0.78      2000
#    macro avg       0.57      0.57      0.57      2000
# weighted avg       0.77      0.78      0.78      2000
#
#
# Confusion Matrix:
#  [[1469  219]
#  [ 227   85]]

# %%
from sklearn.svm import SVC
svm_clf = SVC(kernel='linear',
            class_weight='balanced', # penalize
            probability=True)
svm_clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight='balanced', coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
print_score(svm_clf, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# accuracy score: 0.6434
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.65      0.76      6823
#          1.0       0.23      0.60      0.33      1177
#
#     accuracy                           0.64      8000
#    macro avg       0.57      0.62      0.54      8000
# weighted avg       0.80      0.64      0.69      8000
#
#
# Confusion Matrix:
#  [[4445 2378]
#  [ 475  702]]
#
# Average Accuracy: 	 0.6392
# Accuracy SD: 		 0.0248

# %%
print_score(svm_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Test Result:
#
# accuracy score: 0.6425
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.90      0.65      0.76      1688
#          1.0       0.24      0.59      0.34       312
#
#     accuracy                           0.64      2000
#    macro avg       0.57      0.62      0.55      2000
# weighted avg       0.79      0.64      0.69      2000
#
#
# Confusion Matrix:
#  [[1102  586]
#  [ 129  183]]

# %%
bbc_clf=BalancedBaggingClassifier(max_features=df_X.shape[1], n_estimators=500, replacement=True,
                              sampling_strategy='majority', random_state=42)
bbc_clf.fit(X_train,y_train)
# Out:
# BalancedBaggingClassifier(base_estimator=None, bootstrap=True,
#                           bootstrap_features=False, max_features=42,
#                           max_samples=1.0, n_estimators=500, n_jobs=1,
#                           oob_score=False, random_state=42, ratio=None,
#                           replacement=True, sampling_strategy='majority',
#                           verbose=0, warm_start=False)

# %%
print_score(bbc_clf, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# accuracy score: 0.9095
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94      6823
#          1.0       0.62      1.00      0.76      1177
#
#     accuracy                           0.91      8000
#    macro avg       0.81      0.95      0.85      8000
# weighted avg       0.94      0.91      0.92      8000
#
#
# Confusion Matrix:
#  [[6099  724]
#  [   0 1177]]
#
# Average Accuracy: 	 0.7170
# Accuracy SD: 		 0.0132

# %%
print_score(bbc_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Test Result:
#
# accuracy score: 0.7255
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.87      0.79      0.83      1688
#          1.0       0.24      0.36      0.29       312
#
#     accuracy                           0.73      2000
#    macro avg       0.56      0.58      0.56      2000
# weighted avg       0.77      0.73      0.75      2000
#
#
# Confusion Matrix:
#  [[1338  350]
#  [ 199  113]]

# %%
#start
start_res_bbag_w_lgbm_clf = time.time()

# Balanced Bagging Classifier
res_bbag_w_lgbm_clf = BalancedBaggingClassifier(base_estimator=LGBMClassifier(learning_rate =0.03, 
                                                                          max_depth=40, 
                                                                          min_data_in_leaf=10,
                                                                          n_estimators=500, 
                                                                          num_leaves=50, 
                                                                          random_state = 42), 
                                            max_features=df_X.shape[1], n_estimators=500, 
                                            replacement=True,
                                            random_state=42)
res_bbag_w_lgbm_clf.fit(X_train, y_train)
# Out:
# BalancedBaggingClassifier(base_estimator=LGBMClassifier(boosting_type='gbdt',
#                                                         class_weight=None,
#                                                         colsample_bytree=1.0,
#                                                         importance_type='split',
#                                                         learning_rate=0.03,
#                                                         max_depth=40,
#                                                         min_child_samples=20,
#                                                         min_child_weight=0.001,
#                                                         min_data_in_leaf=10,
#                                                         min_split_gain=0.0,
#                                                         n_estimators=500,
#                                                         n_jobs=-1,
#                                                         num_leaves=50,
#                                                         objective=None,
#                                                         random_state=42,
#                                                         reg_alpha=0.0,
#                                                         reg_lambda=0.0,
#                                                         silent=True,
#                                                         subsample=1.0,
#                                                         subsample_for_bin=200000,
#                                                         subsample_freq=0),
#                           bootstrap=True, bootstrap_features=False,
#                           max_features=42, max_samples=1.0, n_estimators=500,
#                           n_jobs=1, oob_score=False, random_state=42,
#                           ratio=None, replacement=True,
#                           sampling_strategy='auto', verbose=0,
#                           warm_start=False)

# %%
print_score(res_bbag_w_lgbm_clf, X_train, y_train, X_test, y_test, train=True)
# Out:
# Train Result:
#
# accuracy score: 0.8427
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      0.82      0.90      6823
#          1.0       0.48      1.00      0.65      1177
#
#     accuracy                           0.84      8000
#    macro avg       0.74      0.91      0.77      8000
# weighted avg       0.92      0.84      0.86      8000
#
#
# Confusion Matrix:
#  [[5569 1254]
#  [   4 1173]]
#
# Average Accuracy: 	 0.6863
# Accuracy SD: 		 0.0085

# %%
print_score(res_bbag_w_lgbm_clf, X_train, y_train, X_test, y_test, train=False)
# Out:
# Test Result:
#
# accuracy score: 0.7025
#
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.74      0.81      1688
#          1.0       0.26      0.48      0.34       312
#
#     accuracy                           0.70      2000
#    macro avg       0.57      0.61      0.57      2000
# weighted avg       0.79      0.70      0.73      2000
#
#
# Confusion Matrix:
#  [[1255  433]
#  [ 162  150]]
